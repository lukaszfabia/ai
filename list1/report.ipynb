# %% [markdown]
# # Laboratorium 1 - A* vs Dijkstra / Tabu search
# ### Lukasz Fabia 272724

# %% [markdown]
# ### Jak zacząć?
#
# Python3, najlepiej wersja > 3.11.
#
# ```bash
# python -m venv .venv
# source .venv/bin/activate
# pip install -r requirements.txt
# ```

# %% [markdown]
# ## Teoria i cel
#
# Celem tego zdania jest znalezienie najkrótszego (min. droga) przejazdu MPK lub przejechanie z punktu A do B w najkrótszym czasie (min. czasu).
#
# Do tego problemu optymalizacji należy wykorzystać dwa popularne algorytmy do wyszukiwania najktrótszych ścieżek - A* i Dijkstra.
#
# ---
#
# ### Dijkstra
#
# **Algorytm zachłanny**, znajdujący najkrótszą ścieżkę od węzła startowego do wszystkich innych węzłów w grafie. Wykorzstuje wagi (u mnie i w zadaniu korzysta on z kosztu czasu).
#
# ### A*
#
# Jest sprowadzalny do **Dijkstry**. Można powiedzieć, że jest taką ulepszoną wersją i jest częściej używany ze względu na optymalność. A* korzysta z heurystyk, żeby oszacować, czy opłaca się wybierać taka a nie inną ścieżkę. Warto dodać, że działa to gdy wiemy czego szukamy, czyli znany jest _target_.

# %% [markdown]
# ## Wgląd do danych
#
# Pierwsze 5 wierszy. Z racji tego, że jednym z czynników, którym będziemy się kierować przy wybieraniu trasy będzie czas no to warto różnicę, która będzie kosztem danej ścieżki.

# %%
from parser import get_df
df = get_df()

df.head()
# Out:
#         company line departure_time arrival_time            start_stop  \
# 0  MPK Autobusy    A       20:52:00     20:53:00   Zajezdnia Obornicka
# 1  MPK Autobusy    A       20:53:00     20:54:00              Paprotna
# 2  MPK Autobusy    A       20:54:00     20:55:00  Obornicka (Wołowska)
# 3  MPK Autobusy    A       20:55:00     20:57:00            Bezpieczna
# 4  MPK Autobusy    A       20:57:00     20:59:00              Bałtycka
#
#                end_stop  start_stop_lat  start_stop_lon  end_stop_lat  \
# 0              Paprotna       51.148737       17.021069     51.147752
# 1  Obornicka (Wołowska)       51.147752       17.020539     51.144385
# 2            Bezpieczna       51.144385       17.023735     51.141360
# 3              Bałtycka       51.141360       17.026376     51.136632
# 4         Broniewskiego       51.136632       17.030617     51.135851
#
#    end_stop_lon
# 0     17.020539
# 1     17.023735
# 2     17.026376
# 3     17.030617
# 4     17.037383

# %% [markdown]
# ## Jak zbudowałem strukturę grafu?
#
# Generalnie w `/models/graph.py` mamy całą strukturę składa się ona z `Node`, `Edge` i coś co agreguje w sobie węzły, czyli graf. W klasie grafu znajduje się tylko słownik [ulica: węzeł].
#
# Kolejnym krokiem było parsowanie danych i wrzucenie ich do grafu. Iterowałem po wierszach i:
#
# 1. Wyciągałem dane z wiersza i robiłem z tego krawędź.
#
# 2. Dodawałem startowy i końcowy przystanek do słownika. Dodawanie działa w taki sposób, że jeśli ulicy nie ma w kluczach to dodaje dane tej ulicy pod tym kluczem.
#
# 3. Aktualizacja krawędzi, czyli do listy startowego węzła dodaje nowy edge z podpiętymi węzłami.
#
#
# W ten sposób, wystarczy utworzyć obiekt i otrzymujemy `Graf skierowany ważony`. Gdzie **waga** to czas przejazdu w minutach z A do B, a **skierowany** dlatego, że dodaje nową krawędź do startowego node'a. Więcej na temat struktury w kodzie źródłowym [models/graph.py](models/graph.py).
#
# Ostatnia uwaga, przyjąłem, że przy szukaniu połączenia (krawędzi) mogę czekać maksymalnie **15 minut** (czyli od teraz + 15 minut), aby ograniczyć liczbę bezsensownych połączeń. Przykład: jestem na Grunwaldzie, a algorytm proponuje mi połączenie, które odjeżdża za godzinę, ale podróż trwa tylko **12 minut do celu**. Taka optymalizacja.

# %% [markdown]
# ## Strategie działania
#
# Ten problem można fajnie rozwiązać za pomoca strategii. Logika leży tylko w wybieraniu najbardziej **optymalnej** ścieżki. Zatem zbudowałem sobie szkielet z częścią wspólną tych algorytmów i będę manipulować tylko w konkretnych implementacjach wyborem ścieżki. W ten sposób będzie można tworzyć łatwiej nowe odmiany tych algorytmów.
#
# **Odpowiedź** na konieć to jest czas w formacie `HH:MM:SS`, żeby było czytelniej, _liczba odwiedzonych wierzchołków_ i _czas wykonania_(w ms).

# %% [markdown]
# ### Zadanie 1a
#
# Algorytm wyszukiwania najkrótszej ścieżki z A do B za pomocą algorytmu Dijkstry w oparciu o kryterium czasu.

# %% [markdown]
# ### Inicjalizacja grafu

# %%
from parser import to_graph
from dijkstra import Dijkstra
from a import AStarMinTime, AStarMinTransfers, AStarModified
from datetime import time


g = to_graph()

# %%
# Times
t1 = time(hour=8, minute=18, second=0)
t2 = time(hour=20, minute=50, second=0)
t3 = time(hour=7, minute=20, second=0)

# %% [markdown]
# #### Wnioski
#
# 1. Minimalny czas podróży
#
#     - gwarantuje nam, że koszt faktycznie będzie najmniejszy w moim przypadku - czas podróży, ale gdy warunki będą idealne tj. brak opóźnień tramwajów.
#
#     - można pomyśleć nad algorytmem, który obsłuży sytuacje losowe.
#
# 2. Liczba odwiedzonych wierzchołków
#
#     - jest ona całkiem spora, gdy w gre wchodzi trudniejsza trasa na odcinku **Wyszyńskiego** - **Wielka** odwiedził aż _10323_.
#
# 3. Performance
#
#     - długi czas wykonania się dla tras gdzie mamy kilka przystanków to kilkanaście ms, ale liczba rośnie w przypadku trudniejszych odcinków. Jest to spowodowane przeszukiwaniem wszerz co też nijako wiąże się z dużą ilością odwiedzonych wierzchołków.
#
#     - sam język nie jest demonem prędkości, można przepisać na coś szybszego jak (np. Rust, C/C++).
#
# 4. Optymalizacje
#
#     - użycie algorytmu z heurystyką np. A*

# %%
d_engine = Dijkstra(g)

# _ = d_engine.search("Muchobór Wielki", "Mroźna", t1)
_ = d_engine.search("Zajezdnia Obornicka", "Bałtycka", t2)
# _ = d_engine.search("Wyszyńskiego", "PL. GRUNWALDZKI", t3)
# Out:
# It took: 7.06 ms
#
# ====================================================================================================
# Results for Dijkstra:
# ====================================================================================================
# Line  Departure   Start Stop                    Arrival     End Stop                      Cost
# ----------------------------------------------------------------------------------------------------
# A     20:52:00    Zajezdnia Obornicka           20:53:00    Paprotna                       3
# A     20:53:00    Paprotna                      20:54:00    Obornicka (Wołowska)           4
# A     20:54:00    Obornicka (Wołowska)          20:55:00    Bezpieczna                     5
# A     20:55:00    Bezpieczna                    20:57:00    Bałtycka                       7
# ----------------------------------------------------------------------------------------------------
#
# Total time (Dijkstra): 00:07:00
# Total visited nodes: 250
# ====================================================================================================

# %% [markdown]
# ### Zadanie 1b
# Algorytm wyszukiwania najkrótszej ścieżki z A do B za pomocą algorytmu A* w oparciu o kryterium czasu.

# %% [markdown]
# Jako, że A* to jest modyfikacja Dijkstry to po prostu wartość `priority` to będzie strategia obliczania kosztu dla mojej klasy w tym wypadku klasycznego A*. Poniżej snipped kodu z [a.py](a.py) z liczeniem priorytetu.
#
# ```python
# priority = self.cost_strategy(
#               new_cost=new_cost,
#               end_node=end_node,
#               next_end_node=next_edge.end_node,
#           )
# ```
#
# A tutaj heurystyka, zastosowana w szukaniu obiecującej ścieżki. Akturat do policzenia odległość użyłem biblioteki `geopy` ze względu na współrzędne geograficzne. Wszystkie heurystyki znajdują się w [search.py](search.py).
#
# ```python
# def cost_strategy(self, new_cost, **kwargs):
#     return new_cost + self._geo_heuristic(
#         a=kwargs["end_node"], b=kwargs["next_end_node"]
#     )
# ```

# %% [markdown]
# #### Wnioski
#
# 1. Minimalny czas podróży
#
#     - rozwiązanie jest gorsze jak można było się spodziewać, ale bardzo szybko je dostajemy
#
#     - warto dodać, że jest to zależne od heurystyki
#
#
# 2. Liczba odwiedzonych wierzchołków
#
#     - liczba jest o wiele mniejsza od rozwiązania problemu za pomocą **Dijkstry**
#
#     - jest to spowodowane użyciem heurystyki, która przeszukuje rokujące węzły
#
#     - przy trasie najdłuższej odwiedzonych było **735** wierzchołków, gdzie w poprzednim teście przy wykorzystaniu **Dijkstry** było to _10323_.
#
#
# 3. Performance
#
#     - tu jest znaczenie lepiej bo nie przeszukujemy wszystkiego
#
# 4. Opytmalizacje
#
#     - można dodać heurystyke, która by sprawdzała kierunek, którym ma się kierować na podstawie kątów obliczanych z koordynatów punktu A i B.

# %%
a_engine = AStarMinTime(g)
print(t2)
_ = a_engine.search("Muchobór Wielki", "Mroźna", t1)
_ = a_engine.search("Zajezdnia Obornicka", "Bałtycka", t2)
_ = a_engine.search("Wyszyńskiego", "PL. GRUNWALDZKI", t3)
# Out:
# 20:50:00
# It took: 1184.31 ms
#
# ====================================================================================================
# Results for AStarMinTime:
# ====================================================================================================
# Line  Departure   Start Stop                    Arrival     End Stop                      Cost
# ----------------------------------------------------------------------------------------------------
# 119   08:21:00    Muchobór Wielki               08:22:00    Stanisławowska (W.K. Forma     4
# 119   08:22:00    Stanisławowska (W.K. Forma    08:23:00    Trawowa                        5
# 119   08:23:00    Trawowa                       08:24:00    Krzemieniecka                  6
# 119   08:24:00    Krzemieniecka                 08:25:00    Końcowa                        7
# 119   08:25:00    Końcowa                       08:27:00    Ostrowskiego                   9
# 119   08:27:00    Ostrowskiego                  08:28:00    FAT                            10
# 14    08:30:00    FAT                           08:32:00    Aleja Pracy                    14
# 14    08:32:00    Aleja Pracy                   08:33:00    Ojca Beyzyma                   15
# 14    08:33:00    Ojca Beyzyma                  08:35:00    Mielecka                       17
# 14    08:35:00    Mielecka                      08:36:00    Gajowicka                      18
# 14    08:36:00    Gajowicka                     08:38:00    Hallera                        20
# 17    08:38:00    Hallera                       08:39:00    Sztabowa                       21
# 17    08:39:00    Sztabowa                      08:40:00    Rondo                          22
# 17    08:40:00    Rondo                         08:41:00    Wielka                         23
# 2     08:41:00    Wielka                        08:42:00    Zaolziańska                    24
# 2     08:42:00    Zaolziańska                   08:45:00    Arkady (Capitol)               27
# 2     08:45:00    Arkady (Capitol)              08:48:00    DWORZEC GŁÓWNY                 30
# N     08:49:00    DWORZEC GŁÓWNY                08:52:00    GALERIA DOMINIKAŃSKA           34
# N     08:52:00    GALERIA DOMINIKAŃSKA          08:55:00    Urząd Wojewódzki (Muzeum N     37
# N     08:55:00    Urząd Wojewódzki (Muzeum N    08:56:00    Katedra                        38
# N     08:56:00    Katedra                       08:58:00    Ogród Botaniczny               40
# N     08:58:00    Ogród Botaniczny              09:00:00    Wyszyńskiego                   42
# N     09:00:00    Wyszyńskiego                  09:01:00    Damrota                        43
# N     09:01:00    Damrota                       09:04:00    KROMERA                        46
# N     09:04:00    KROMERA                       09:06:00    Kromera (Czajkowskiego)        48
# N     09:06:00    Kromera (Czajkowskiego)       09:07:00    Grudziądzka                    49
# N     09:07:00    Grudziądzka                   09:09:00    Brücknera                      51
# D     09:09:00    Brücknera                     09:13:00    Psie Pole                      55
# D     09:13:00    Psie Pole                     09:14:00    Psie Pole (Rondo Lotników      56
# 121   09:14:00    Psie Pole (Rondo Lotników     09:15:00    MULICKA                        57
# 121   09:15:00    MULICKA                       09:16:00    Gorlicka                       58
# 921   09:30:00    Gorlicka                      09:31:00    Palacha                        73
# 921   09:31:00    Palacha                       09:32:00    Zgorzelisko                    74
# 921   09:32:00    Zgorzelisko                   09:32:00    Kurlandzka                     74
# 921   09:32:00    Kurlandzka                    09:33:00    Mroźna                         75
# ----------------------------------------------------------------------------------------------------
#
# Total time (AStarMinTime): 01:15:00
# Total visited nodes: 66357
# ====================================================================================================
#
# It took: 5.91 ms
#
# ====================================================================================================
# Results for AStarMinTime:
# ====================================================================================================
# Line  Departure   Start Stop                    Arrival     End Stop                      Cost
# ----------------------------------------------------------------------------------------------------
# A     20:52:00    Zajezdnia Obornicka           20:53:00    Paprotna                       3
# A     20:53:00    Paprotna                      20:54:00    Obornicka (Wołowska)           4
# A     20:54:00    Obornicka (Wołowska)          20:55:00    Bezpieczna                     5
# A     20:55:00    Bezpieczna                    20:57:00    Bałtycka                       7
# ----------------------------------------------------------------------------------------------------
#
# Total time (AStarMinTime): 00:07:00
# Total visited nodes: 250
# ====================================================================================================
#
# It took: 54.74 ms
#
# ====================================================================================================
# Results for AStarMinTime:
# ====================================================================================================
# Line  Departure   Start Stop                    Arrival     End Stop                      Cost
# ----------------------------------------------------------------------------------------------------
# N     07:24:00    Wyszyńskiego                  07:26:00    Ogród Botaniczny               6
# 9     07:27:00    Ogród Botaniczny              07:28:00    Górnickiego                    8
# 9     07:28:00    Górnickiego                   07:29:00    Piastowska                     9
# 16    07:31:00    Piastowska                    07:35:00    PL. GRUNWALDZKI                15
# ----------------------------------------------------------------------------------------------------
#
# Total time (AStarMinTime): 00:15:00
# Total visited nodes: 3290
# ====================================================================================================

# %% [markdown]
# #### Zadanie 1c
#
# **Minimalizacja liczby przesiadek**. Intuicja podpowiada, że trzeba będzie wprowadzić coś w stylu kary, dodatkowego kosztu doliczanego do ścieżki, która może i jest najkrótszą, ale wymaga przesiadki właśnie. W ten sposób algorytm będzie brał pod uwagę ścieżki, które nie wymagają zmiany `line`. Tak naprawdę cała zabawa sprowadziła się do dodatania do nowego kosztu sprawdzienie ile kosztować przesiadka. Poniżej _snipped_ z source kodu, który znajduje się [a.py](a.py).
#
# ```python
# new_cost = (
#             cost_so_far[current_node]
#             + self.graph.compute_cost(next_edge, current_time)
#             + self.graph.line_change_cost(
#                 edge=came_from[current_node.name], next_edge=next_edge
#             )
#         )
# ```

# %% [markdown]
# #### Wnioski
#
# Wynik jest podobny do zwykłego A*, gdzie minimalizowany był czas. Tutaj mieliśmy minimalizować przesiadki i powiedzmy, że się udało na przykładowych trasach. Mamy mniej zmian linii, czas nieznaczenie się wydłużył i widać doliczoną karę za przesiadkę. W niektórych testach liczba odwiedzonych wierzchołków jest mniejsza.

# %%
a_mut_engine = AStarMinTransfers(g)

_ = a_mut_engine.search("Muchobór Wielki", "Mroźna", t1)
_ = a_mut_engine.search("Zajezdnia Obornicka", "Bałtycka", t2)
_ = a_mut_engine.search("Wyszyńskiego", "PL. GRUNWALDZKI", t3)
# Out:
# It took: 1162.19 ms
#
# ====================================================================================================
# Results for AStarMinTransfers:
# ====================================================================================================
# Line  Departure   Start Stop                    Arrival     End Stop                      Cost
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
#
# Total time (AStarMinTransfers): 00:15:00
# Total visited nodes: 3290
# ====================================================================================================

# %% [markdown]
# # Podsumowanie pierwszej części listy
#
# Generalnie zgodnie z założeniem Dijkstra zwraca najlepsze wyniki w nie najlepszym czasie. Udało się w miarę sensownie zaimplementować A* (minimalizacja czasu albo przystanków), który zwaraca dobrą odpowiedź w naprawdę fajnym czasie. Udało się napisać względnie bez duplikacji kodu przez co łatwo można pisać swoje implementacje, które jakoś optymalizują wybór ścieżki.
#
# Największy problem jednak sprawił sam `Python`, jako osoba, która raczej jest przyzwyczajona do **Go**, **TypeScripta**, **Javy** no to było ciężko debugować, ale trzeba przyznać, że _JupyterNotebook_ pomógł w procesie. Last but not least, ułatwieniem było, że doba nie trwała 24h tylko więcej to pomogło się skupiać na policzeniu kosztu w minutach między węzłami (przystankami).

# %% [markdown]
# ## Tabu Search
#
# **Metaheurystyka** polegająca na interacyjnym przeszukiwaniu sąsiedztwa, uwzględnia zestaw ruchów niedozwolonych. Wymaga dodakowej pamięci w porównaniu do **przeszukiwania lokalnego**.
#
# W zadaniu należy przechejać przez wszystkie przystanki i wrócić się do punktu początkowego po przez minimalizację:
#
# - czasu
#
# - przesiadek
#
# Podobnie jak w poprzednim zadaniu tutaj też postarałem się aby nie duplikować kodu i poprostu parametry w zadaniu będę przyjmować opcjonalnie.
#
# W implementacji `wycieczki` po mieście użyłem A*, ponieważ Dijkstra wykonywałby się znacznie dłużej.

# %% [markdown]
# ## Przykład użycia

# %%
from tabu import Tabu
max_iter = 111
points = ["PL. GRUNWALDZKI", "Dubois", "DWORZEC GŁÓWNY"]
src = "Wyszyńskiego"
t = Tabu(g=g, t=t2, points=points, src=src, max_iter=max_iter)

# %%
best_sln = t.search()
t.set_points(best_sln)
t.go_on_a_trip()
# Out:
# It took: 1223.98 ms
# It took: 149.00 ms
#
# ====================================================================================================
# Results for AStarMinTime:
# ====================================================================================================
# Line  Departure   Start Stop                    Arrival     End Stop                      Cost
# ----------------------------------------------------------------------------------------------------
# N     20:50:00    Wyszyńskiego                  20:51:00    Damrota                        1
# N     20:51:00    Damrota                       20:54:00    KROMERA                        4
# D     20:56:00    KROMERA                       20:57:00    Berenta                        7
# D     20:57:00    Berenta                       20:58:00    Kasprowicza                    8
# D     20:58:00    Kasprowicza                   20:59:00    Syrokomli                      9
# D     20:59:00    Syrokomli                     21:00:00    Pola                           10
# D     21:00:00    Pola                          21:02:00    Broniewskiego                  12
# K     21:06:00    Broniewskiego                 21:08:00    Bałtycka                       18
# 103   21:21:00    Bałtycka                      21:24:00    Kleczkowska                    34
# 714   21:26:00    Kleczkowska                   21:28:00    PL. STASZICA                   38
# 714   21:28:00    PL. STASZICA                  21:29:00    DWORZEC NADODRZE               39
# 15    21:35:00    DWORZEC NADODRZE              21:36:00    Paulińska                      46
# 15    21:36:00    Paulińska                     21:38:00    Dubois                         48
# 15    21:38:00    Dubois                        21:40:00    Pomorska                       50
# 18    21:42:00    Pomorska                      21:43:00    Mosty Pomorskie                53
# K     21:45:00    Mosty Pomorskie               21:47:00    Rynek                          57
# 7     21:53:00    Rynek                         21:55:00    Narodowe Forum Muzyki          65
# 7     21:55:00    Narodowe Forum Muzyki         21:58:00    Renoma                         68
# 7     21:58:00    Renoma                        22:00:00    Arkady (Capitol)               70
# 2     22:02:00    Arkady (Capitol)              22:04:00    DWORZEC GŁÓWNY                 74
# ----------------------------------------------------------------------------------------------------
#
# Total time (AStarMinTime):
# 7     23:53:00    Renoma                        23:55:00    Arkady (Capitol)               19
# 250   24:02:00    Arkady (Capitol)              24:04:00    EPI                            28
# 250   24:04:00    EPI                           24:05:00    DWORZEC GŁÓWNY                 29
# 110   24:12:00    DWORZEC GŁÓWNY                24:13:00    Wzgórze Partyzantów            37
# 110   24:13:00    Wzgórze Partyzantów           24:15:00    GALERIA DOMINIKAŃSKA           39
# 246   24:15:00    GALERIA DOMINIKAŃSKA          24:18:00    Urząd Wojewódzki (Muzeum N     42
# 246   24:18:00    Urząd Wojewódzki (Muzeum N    24:19:00    Katedra                        43
# 246   24:19:00    Katedra                       24:20:00    Ogród Botaniczny               44
# 246   24:20:00    Ogród Botaniczny              24:22:00    Wyszyńskiego                   46
# ----------------------------------------------------------------------------------------------------
#
# Total time (AStarMinTime): 00:46:00
# Total visited nodes: 2165
# ====================================================================================================

# %% [markdown]
# ### Tabu Search dobór długości tablicy T (b)
#
# Dostosowuje długość listy tabu w trakcie działania, w zależności od postępu algorytmu. Długość T to 10, ale można zmienić.

# %%
best_sln = t.dynamic_search()
t.set_points(best_sln)
t.go_on_a_trip()
# Out:
# It took: 2211.31 ms
# It took: 0.01 ms
# It took: 112.43 ms
#
# ====================================================================================================
# Results for AStarMinTime:
# ====================================================================================================
# Line  Departure   Start Stop                    Arrival     End Stop                      Cost
# ----------------------------------------------------------------------------------------------------
# N     20:50:00    Wyszyńskiego                  20:51:00    Damrota                        1
# N     20:51:00    Damrota                       20:54:00    KROMERA                        4
# D     20:56:00    KROMERA                       20:57:00    Berenta                        7
# D     20:57:00    Berenta                       20:58:00    Kasprowicza                    8
# D     20:58:00    Kasprowicza                   20:59:00    Syrokomli                      9
# D     20:59:00    Syrokomli                     21:00:00    Pola                           10
# D     21:00:00    Pola                          21:02:00    Broniewskiego                  12
# K     21:06:00    Broniewskiego                 21:08:00    Bałtycka                       18
# 103   21:21:00    Bałtycka                      21:24:00    Kleczkowska                    34
# 714   21:26:00    Kleczkowska                   21:28:00    PL. STASZICA                   38
# 714   21:28:00    PL. STASZICA                  21:29:00    DWORZEC NADODRZE               39
# 15    21:35:00    DWORZEC NADODRZE              21:36:00    Paulińska                      46
# 15    21:36:00    Paulińska                     21:38:00    Dubois                         48
# ----------------------------------------------------------------------------------------------------
#
# Total time (AStarMinTime): 00:48:00
# Total visited nodes: 5490
# ====================================================================================================
#
# It took: 533.87 ms
#
# ====================================================================================================
# Results for AStarMinTime:
# ====================================================================================================
# Line  Departure   Start Stop                    Arrival     End Stop                      Cost
# ----------------------------------------------------------------------------------------------------
# 15    21:45:00    Dubois                        21:47:00    Paulińska                      9
# 15    21:47:00    Paulińska                     21:49:00    DWORZEC NADODRZE               11
# 1     21:50:00    DWORZEC NADODRZE              21:52:00    Słowiańska                     14
# 1     21:52:00    Słowiańska                    21:54:00    Nowowiejska                    16
# 1     21:54:00    Nowowiejska                   21:56:00    Wyszyńskiego                   18
# ----------------------------------------------------------------------------------------------------
#
# Total time (AStarMinTime): 00:18:00
# Total visited nodes: 26378
# ====================================================================================================
#
# It took: 139.84 ms
#
# ====================================================================================================
# Results for AStarMinTime:
# ====================================================================================================
# Line  Departure   Start Stop                    Arrival     End Stop                      Cost
# ----------------------------------------------------------------------------------------------------
# 16    22:03:00    Wyszyńskiego                  22:05:00    Nowowiejska                    9
# 16    22:05:00    Nowowiejska                   22:06:00    Słowiańska                     10
# 16    22:06:00    Słowiańska                    22:08:00    DWORZEC NADODRZE               12
# 144   22:12:00    DWORZEC NADODRZE              22:14:00    Paulińska                      18
# 144   22:14:00    Paulińska                     22:16:00    Dubois                         20
# 132   22:17:00    Dubois                        22:20:00    Rynek                          24
# 7     22:33:00    Rynek                         22:35:00    Narodowe Forum Muzyki          39
# 7     22:35:00    Narodowe Forum Muzyki         22:38:00    Renoma                         42
# 7     22:38:00    Renoma                        22:40:00    Arkady (Capitol)               44
# 2     22:42:00    Arkady (Capitol)              22:44:00    DWORZEC GŁÓWNY                 48
# ----------------------------------------------------------------------------------------------------
#
# Total time (AStarMinTime): 00:48:00
# Total visited nodes: 6801
# ====================================================================================================
#
# It took: 133.93 ms
#
# ====================================================================================================
# Results for AStarMinTime:
# ====================================================================================================
# Line  Departure   Start Stop                    Arrival     End Stop                      Cost
# ----------------------------------------------------------------------------------------------------
# 22    22:46:00    DWORZEC GŁÓWNY                22:48:00    Pułaskiego                     4
# 22    22:48:00    Pułaskiego                    22:51:00    Hubska (Dawida)                7
# 22    22:51:00    Hubska (Dawida)               22:52:00    Prudnicka                      8
# 22    22:52:00    Prudnicka                     22:53:00    Kamienna                       9
# 22    22:53:00    Kamienna                      22:55:00    Bardzka                        11
# 22    22:55:00    Bardzka                       22:56:00    Nyska                          12
# 22    22:56:00    Nyska                         22:57:00    Tarnogajska                    13
# 22    22:57:00    Tarnogajska                   22:59:00    Klimasa                        15
# 143   23:03:00    Klimasa                       23:04:00    Armii Krajowej (Bogedaina)     20
# 143   23:04:00    Armii Krajowej (Bogedaina)    23:05:00    Armii Krajowej                 21
# 143   23:05:00    Armii Krajowej                23:07:00    Międzyrzecka                   23
# 143   23:07:00    Międzyrzecka                  23:09:00    Biegasa                        25
# 143   23:09:00    Biegasa                       23:10:00    Chełmońskiego                  26
# 143   23:10:00    Chełmońskiego                 23:12:00    Dembowskiego (Kosiby)          28
# 143   23:12:00    Dembowskiego (Kosiby)         23:13:00    8 Maja                         29
# 115   23:26:00    8 Maja                        23:27:00    Park Szczytnicki               43
# 115   23:27:00    Park Szczytnicki              23:28:00    Mickiewicza                    44
# 115   23:28:00    Mickiewicza                   23:30:00    Kliniki - Politechnika Wro     46
# 115   23:30:00    Kliniki - Politechnika Wro    23:32:00    PL. GRUNWALDZKI                48
# ----------------------------------------------------------------------------------------------------
#
# Total time (AStarMinTime): 00:48:00
# Total visited nodes: 5739
# ====================================================================================================
#
# It took: 153.22 ms
#
# ====================================================================================================
# Results for AStarMinTime:
# ====================================================================================================
# Line  Departure   Start Stop                    Arrival     End Stop                      Cost
# ----------------------------------------------------------------------------------------------------
# 115   23:32:00    PL. GRUNWALDZKI               23:33:00    Reja                           1
# 115   23:33:00    Reja                          23:34:00    Katedra                        2
# 115   23:34:00    Katedra                       23:35:00    Ogród Botaniczny               3
# 115   23:35:00    Ogród Botaniczny              23:37:00    Wyszyńskiego                   5
# ----------------------------------------------------------------------------------------------------
#
# Total time (AStarMinTime): 00:05:00
# Total visited nodes: 3914
# ====================================================================================================

# %% [markdown]
# ### Tabu Search aspiracja (c)
#
# Pozwala zaakceptować rozwiązania z listy tabu, jeśli są lepsze niż poprzednie najlepsze rozwiązanie.

# %%
best_sln = t.aspiration_search()
print(f'Best solution {best_sln}')
t.set_points(best_sln)
t.go_on_a_trip()
# Out:
# It took: 4166.48 ms
# Best solution ['Wyszyńskiego', 'Wyszyńskiego', 'Wyszyńskiego', 'PL. GRUNWALDZKI', 'DWORZEC GŁÓWNY', 'Dubois']
# It took: 0.01 ms
# It took: 0.00 ms
# It took: 0.00 ms
# It took: 33.91 ms
#
# ====================================================================================================
# Results for AStarMinTime:
# ====================================================================================================
# Line  Departure   Start Stop                    Arrival     End Stop                      Cost
# ----------------------------------------------------------------------------------------------------
# A     20:50:00    Wyszyńskiego                  20:52:00    Ogród Botaniczny               2
# 19    20:58:00    Ogród Botaniczny              20:59:00    Górnickiego                    9
# 19    20:59:00    Górnickiego                   21:00:00    Piastowska                     10
# 19    21:00:00    Piastowska                    21:04:00    PL. GRUNWALDZKI                14
# ----------------------------------------------------------------------------------------------------
#
# Total time (AStarMinTime): 00:14:00
# Total visited nodes: 1680
# ====================================================================================================
#
# It took: 64.19 ms
#
# ====================================================================================================
# Results for AStarMinTime:
# ====================================================================================================
# Line  Departure   Start Stop                    Arrival     End Stop                      Cost
# ----------------------------------------------------------------------------------------------------
#
# 122   23:07:00    Głogowska                     23:08:00    Szczepin                       81
# 122   23:08:00    Szczepin                      23:09:00    Inowrocławska                  82
# 122   23:09:00    Inowrocławska                 23:10:00    PL. SOLIDARNOŚCI               83
# 122   23:10:00    PL. SOLIDARNOŚCI              23:12:00    PL. JANA PAWŁA II              85
# 4     23:15:00    PL. JANA PAWŁA II             23:17:00    Kępa Mieszczańska              90
# 4     23:17:00    Kępa Mieszczańska             23:19:00    Pomorska                       92
# 4     23:19:00    Pomorska                      23:21:00    Dubois                         94
# ----------------------------------------------------------------------------------------------------
#
# Total time (AStarMinTime): 01:34:00
# Total visited nodes: 11666
# ====================================================================================================
#
# It took: 202.08 ms
#
# ====================================================================================================
# Results for AStarMinTime:
# ====================================================================================================
# Line  Departure   Start Stop                    Arrival     End Stop                      Cost
# ----------------------------------------------------------------------------------------------------
# 15    23:23:00    Dubois                        23:24:00    Paulińska                      3
# 15    23:24:00    Paulińska                     23:25:00    DWORZEC NADODRZE               4
# 15    23:25:00    DWORZEC NADODRZE              23:27:00    Słowiańska                     6
# 240   23:35:00    Słowiańska                    23:37:00    Nowowiejska                    16
# 240   23:37:00    Nowowiejska                   23:38:00    Wyszyńskiego                   17
# ----------------------------------------------------------------------------------------------------
#
# Total time (AStarMinTime): 00:17:00
# Total visited nodes: 5312
# ====================================================================================================

# %% [markdown]
# ### Tabu Search sampling (d)
#
# Wybieram losowo k list z sąsiadami, w celu zwiększenia różnorodności poszukiwań

# %%
best_sln = t.sampling_search()
print(f'Best solution {best_sln}')
t.set_points(best_sln)
t.go_on_a_trip()
# Out:
# It took: 7119.45 ms
# Best solution ['Dubois', 'Wyszyńskiego', 'DWORZEC GŁÓWNY', 'Wyszyńskiego', 'PL. GRUNWALDZKI', 'Wyszyńskiego', 'Wyszyńskiego']
# It took: 115.41 ms
#
# ====================================================================================================
# Results for AStarMinTime:
# ====================================================================================================
# Line  Departure   Start Stop                    Arrival     End Stop                      Cost
# ----------------------------------------------------------------------------------------------------
# N     20:50:00    Wyszyńskiego                  20:51:00    Damrota                        1
# N     20:51:00    Damrota                       20:54:00    KROMERA                        4
# D     20:56:00    KROMERA                       20:57:00    Berenta                        7
# D     20:57:00    Berenta                       20:58:00    Kasprowicza                    8
# D     20:58:00    Kasprowicza                   20:59:00    Syrokomli                      9
# D     20:59:00    Syrokomli                     21:00:00    Pola                           10
# D     21:00:00    Pola                          21:02:00    Broniewskiego                  12
# K     21:06:00    Broniewskiego                 21:08:00    Bałtycka                       18
# 103   21:21:00    Bałtycka                      21:24:00    Kleczkowska                    34
# 714   21:26:00    Kleczkowska                   21:28:00    PL. STASZICA                   38
# 714   21:28:00    PL. STASZICA                  21:29:00    DWORZEC NADODRZE               39
# 15    21:35:00    DWORZEC NADODRZE              21:36:00    Paulińska                      46
# 15    21:36:00    Paulińska                     21:38:00    Dubois                         48
# ----------------------------------------------------------------------------------------------------
#
# Total time (AStarMinTime): 00:48:00
# Total visited nodes: 5490
# ====================================================================================================
#
# It took: 568.82 ms
#
# ====================================================================================================
# Results for AStarMinTime:
# ====================================================================================================
# Line  Departure   Start Stop                    Arrival     End Stop                      Cost
# ----------------------------------------------------------------------------------------------------
# 15    21:45:00    Dubois                        21:47:00    Paulińska                      9
# 15    21:47:00    Paulińska                     21:49:00    DWORZEC NADODRZE               11
# 1     21:50:00    DWORZEC NADODRZE              21:52:00    Słowiańska                     14
# 1     21:52:00    Słowiańska                    21:54:00    Nowowiejska                    16
# 1     21:54:00    Nowowiejska                   21:56:00    Wyszyńskiego                   18
# ----------------------------------------------------------------------------------------------------
#
# Total time (AStarMinTime): 00:18:00
# Total visited nodes: 26378
# ====================================================================================================
#
# It took: 138.94 ms
#
# ====================================================================================================
# Results for AStarMinTime:
# ====================================================================================================
# Line  Departure   Start Stop                    Arrival     End Stop                      Cost
# ----------------------------------------------------------------------------------------------------
# 16    22:03:00    Wyszyńskiego                  22:05:00    Nowowiejska                    9
# 16    22:05:00    Nowowiejska                   22:06:00    Słowiańska                     10
# 16    22:06:00    Słowiańska                    22:08:00    DWORZEC NADODRZE               12
# 144   22:12:00    DWORZEC NADODRZE              22:14:00    Paulińska                      18
# 144   22:14:00    Paulińska                     22:16:00    Dubois                         20
# 132   22:17:00    Dubois                        22:20:00    Rynek                          24
# 7     22:33:00    Rynek                         22:35:00    Narodowe Forum Muzyki          39
# 7     22:35:00    Narodowe Forum Muzyki         22:38:00    Renoma                         42
# 7     22:38:00    Renoma                        22:40:00    Arkady (Capitol)               44
# 2     22:42:00    Arkady (Capitol)              22:44:00    DWORZEC GŁÓWNY                 48
# ----------------------------------------------------------------------------------------------------
#
# Total time (AStarMinTime): 00:48:00
# Total visited nodes: 6801
# ====================================================================================================
#
# It took: 434.22 ms
#
# ====================================================================================================
# Results for AStarMinTime:
# ====================================================================================================
# Line  Departure   Start Stop                    Arrival     End Stop                      Cost
# ----------------------------------------------------------------------------------------------------
# 4     22:48:00    DWORZEC GŁÓWNY                22:51:00    Arkady (Capitol)               7
# D     22:54:00    Arkady (Capitol)              22:59:00    GALERIA DOMINIKAŃSKA           15
# 10    23:03:00    GALERIA DOMINIKAŃSKA          23:06:00    Urząd Wojewódzki (Muzeum N     22
# 10    23:06:00    Urząd Wojewódzki (Muzeum N    23:07:00    Katedra                        23
# 111   23:08:00    Katedra                       23:09:00    Ogród Botaniczny               25
# A     23:10:00    Ogród Botaniczny              23:12:00    Wyszyńskiego                   28
# ----------------------------------------------------------------------------------------------------
#
# Total time (AStarMinTime): 00:28:00
# Total visited nodes: 15483
# ====================================================================================================
#
# It took: 25.82 ms
#
# ====================================================================================================
# Results for AStarMinTime:
# ====================================================================================================
# Line  Departure   Start Stop                    Arrival     End Stop                      Cost
# ----------------------------------------------------------------------------------------------------
# 16    23:25:00    Wyszyńskiego                  23:26:00    Prusa                          14
# 16    23:26:00    Prusa                         23:28:00    Piastowska                     16
# 16    23:28:00    Piastowska                    23:31:00    PL. GRUNWALDZKI                19
# ----------------------------------------------------------------------------------------------------
#
# Total time (AStarMinTime): 00:19:00
# Total visited nodes: 913
# ====================================================================================================
#
# It took: 151.22 ms
#
# ====================================================================================================
# Results for AStarMinTime:
# ====================================================================================================
# Line  Departure   Start Stop                    Arrival     End Stop                      Cost
# ----------------------------------------------------------------------------------------------------
# 2     23:31:00    PL. GRUNWALDZKI               23:32:00    Reja                           1
# 2     23:32:00    Reja                          23:33:00    Katedra                        2
# 115   23:34:00    Katedra                       23:35:00    Ogród Botaniczny               4
# 115   23:35:00    Ogród Botaniczny              23:37:00    Wyszyńskiego                   6
# ----------------------------------------------------------------------------------------------------
#
# Total time (AStarMinTime): 00:06:00
# Total visited nodes: 3864
# ====================================================================================================
#
# It took: 0.00 ms
# It took: 0.00 ms

# %% [markdown]
# ## Podsumowanie Tabu

# %% [markdown]
# Ogólnie myślę, że udało się rozwiązać ten problem, **różne warianty tabu** dają różne wyniki, czyli modyfikacje w głównym bloku działają.
#
# Wyniki przedstawiają się następująco (dla mojej kompilacji, niektóre mogą się różnić ze względu na użycie liczb pseudolosowych):
#
#
# | Nazwa          | Czas [min] |
# |----------------|------------|
# | Basic Tabu  | 74 + 60 + 8 + 24 + 46 = 212 |
# | Dynamic Tabu| 48 + 18 + 48 + 48 + 5 = 167 |
# | Aspiracja   | 14 + 43 + 94 + 17 = 168 |
# | Sampling    | 48 + 48 + 18 + 28 + 19 + 6 =  167|
#
# Wyniki standardowego tabu są stosunkowo słabe w porównaniu do pozostałych. Pozostałe metody osiągają wyniki na poziomie, który można uznać za akceptowalny. Wyniki zależą także od dobranych parametrów. Prawdopodobnie w łatwiejszych warunkach algorytmy mogłyby zadziałać lepiej. Warto dodać, że testowałem je w trudnych warunkach, ponieważ około godziny 21 zaczyna być coraz mniej połączeń.
#
# Warto zauważyć, że:
#
# - Algorytm aspiracji daje niski wynik, ale nie wracamy do punktu początkowego.
#
# - Sampling generuje wiele krótkich połączeń.
#
# - Basic Tabu produkuje długie połączenia.
